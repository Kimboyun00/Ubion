# %%
service_key = "2xQhJhK7Olh7ATCkpQsV+o7K/GAmiuKEEH0xajI/OFYeBno7qU2LkF8DFSXLkqoQf88+xyWzgdvlb+Xebvg6fQ=="

# %%
# !pip install requests
# !pip install pprint

# %%
import requests

url = 'http://apis.data.go.kr/1262000/CountryPopulationService2/getCountryPopulationList2'
params ={'serviceKey' : service_key, 'pageNo' : '1', 'numOfRows' : '10', 'cond[country_nm::EQ]' : '가나', 'cond[country_iso_alp2::EQ]' : 'GH', 'returnType' : 'xml' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b"<response><body><dataType>XML</dataType><items><item><country_eng_nm><![CDATA[Ghana]]></country_eng_nm><country_iso_alp2><![CDATA[GH]]></country_iso_alp2><popltn_year>2019</popltn_year><popltn_cnt>31522290</popltn_cnt><country_nm><![CDATA[\xea\xb0\x80\xeb\x82\x98]]></country_nm><popltn_month></popltn_month><popltn_cnt_src><![CDATA[('19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)]]></popltn_cnt_src><popltn_growth><![CDATA[2.09]]></popltn_growth><popltn_growth_src><![CDATA[('19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)]]></popltn_growth_src><popltn_cn></popltn_cn></item><item><country_iso_alp2><![CDATA[GH]]></country_iso_alp2><popltn_year>2018</popltn_year><popltn_cnt>30870641</popltn_cnt><country_eng_nm><![CDATA[Ghana]]></country_eng_nm><popltn_month></popltn_month><popltn_cnt_src><![CDATA[('18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)]]></popltn_cnt_src><popltn_growth><![CDATA[2.12]]></popltn_growth><popltn_growth_src><![CDATA[('18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)]]></popltn_growth_src><popltn_cn></popltn_cn><country_nm><![CDATA[\xea\xb0\x80\xeb\x82\x98]]></country_nm></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>2</totalCount></body><header><resultCode>0</resultCode><resultMsg>\xec\xa0\x95\xec\x83\x81</resultMsg></header></response>"

# %%
# !pip install xmltodict

# %%
import xmltodict

# %%
# xml 데이터를 dict형으로 변환
res_data = xmltodict.parse(response.content)\
    ['response']['body']['items']['item']

# %%
import pandas as pd

# %%
pd.DataFrame(res_data).to_csv("test.csv", index=False)

# %%
pd.read_csv('test.csv')
# Out:
#   country_eng_nm country_iso_alp2  popltn_year  popltn_cnt country_nm  \
# 0          Ghana               GH         2019    31522290         가나
# 1          Ghana               GH         2018    30870641         가나
#
#    popltn_month                           popltn_cnt_src  popltn_growth  \
# 0           NaN  ('19) World Bank (최근 수정일 : 2024.11.13.)           2.09
# 1           NaN  ('18) World Bank (최근 수정일 : 2024.11.13.)           2.12
#
#                          popltn_growth_src  popltn_cn
# 0  ('19) World Bank (최근 수정일 : 2024.11.13.)        NaN
# 1  ('18) World Bank (최근 수정일 : 2024.11.13.)        NaN

# %%
import requests

url = 'http://apis.data.go.kr/1262000/CountryPopulationService2/getCountryPopulationList2'
params ={'serviceKey' : service_key, 
         'pageNo' : '1', 
         'numOfRows' : '10', 
         'returnType' : 'json' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"dataType":"JSON","items":{"item":[{"country_eng_nm":"Ghana","country_iso_alp2":"GH","country_nm":"\xea\xb0\x80\xeb\x82\x98","popltn_cn":null,"popltn_cnt":31522290,"popltn_cnt_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.09,"popltn_growth_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2019},{"country_eng_nm":"Ghana","country_iso_alp2":"GH","country_nm":"\xea\xb0\x80\xeb\x82\x98","popltn_cn":null,"popltn_cnt":30870641,"popltn_cnt_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.12,"popltn_growth_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2018},{"country_eng_nm":"Gabon","country_iso_alp2":"GA","country_nm":"\xea\xb0\x80\xeb\xb4\x89","popltn_cn":null,"popltn_cnt":2242785,"popltn_cnt_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.29,"popltn_growth_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2019},{"country_eng_nm":"Gabon","country_iso_alp2":"GA","country_nm":"\xea\xb0\x80\xeb\xb4\x89","popltn_cn":null,"popltn_cnt":2192012,"popltn_cnt_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.39,"popltn_growth_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2018},{"country_eng_nm":"Guyana","country_iso_alp2":"GY","country_nm":"\xea\xb0\x80\xec\x9d\xb4\xec\x95\x84\xeb\x82\x98","popltn_cn":null,"popltn_cnt":798753,"popltn_cnt_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":1.67,"popltn_growth_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2019},{"country_eng_nm":"Guyana","country_iso_alp2":"GY","country_nm":"\xea\xb0\x80\xec\x9d\xb4\xec\x95\x84\xeb\x82\x98","popltn_cn":null,"popltn_cnt":785514,"popltn_cnt_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.88,"popltn_growth_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2018},{"country_eng_nm":"Gambia","country_iso_alp2":"GM","country_nm":"\xea\xb0\x90\xeb\xb9\x84\xec\x95\x84","popltn_cn":null,"popltn_cnt":2508883,"popltn_cnt_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.58,"popltn_growth_src":"(\'19) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2019},{"country_eng_nm":"Gambia","country_iso_alp2":"GM","country_nm":"\xea\xb0\x90\xeb\xb9\x84\xec\x95\x84","popltn_cn":null,"popltn_cnt":2444916,"popltn_cnt_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_growth":2.64,"popltn_growth_src":"(\'18) World Bank (\xec\xb5\x9c\xea\xb7\xbc \xec\x88\x98\xec\xa0\x95\xec\x9d\xbc : 2024.11.13.)","popltn_month":null,"popltn_year":2018},{"country_eng_nm":"Bailiwick of Guernsey","country_iso_alp2":"GG","country_nm":"\xea\xb1\xb4\xec\xa7\x80","popltn_cn":null,"popltn_cnt":62506,"popltn_cnt_src":null,"popltn_growth":null,"popltn_growth_src":null,"popltn_month":12,"popltn_year":2018},{"country_eng_nm":"Bailiwick of Guernsey","country_iso_alp2":"GG","country_nm":"\xea\xb1\xb4\xec\xa7\x80","popltn_cn":null,"popltn_cnt":null,"popltn_cnt_src":null,"popltn_growth":null,"popltn_growth_src":null,"popltn_month":null,"popltn_year" ...

# %%
# bytes 데이터를 dict
import json

# %%
json.loads(response.content)
# Out:
# {'response': {'body': {'dataType': 'JSON',
#    'items': {'item': [{'country_eng_nm': 'Ghana',
#       'country_iso_alp2': 'GH',
#       'country_nm': '가나',
#       'popltn_cn': None,
#       'popltn_cnt': 31522290,
#       'popltn_cnt_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.09,
#       'popltn_growth_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2019},
#      {'country_eng_nm': 'Ghana',
#       'country_iso_alp2': 'GH',
#       'country_nm': '가나',
#       'popltn_cn': None,
#       'popltn_cnt': 30870641,
#       'popltn_cnt_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.12,
#       'popltn_growth_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2018},
#      {'country_eng_nm': 'Gabon',
#       'country_iso_alp2': 'GA',
#       'country_nm': '가봉',
#       'popltn_cn': None,
#       'popltn_cnt': 2242785,
#       'popltn_cnt_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.29,
#       'popltn_growth_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2019},
#      {'country_eng_nm': 'Gabon',
#       'country_iso_alp2': 'GA',
#       'country_nm': '가봉',
#       'popltn_cn': None,
#       'popltn_cnt': 2192012,
#       'popltn_cnt_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.39,
#       'popltn_growth_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2018},
#      {'country_eng_nm': 'Guyana',
#       'country_iso_alp2': 'GY',
#       'country_nm': '가이아나',
#       'popltn_cn': None,
#       'popltn_cnt': 798753,
#       'popltn_cnt_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 1.67,
#       'popltn_growth_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2019},
#      {'country_eng_nm': 'Guyana',
#       'country_iso_alp2': 'GY',
#       'country_nm': '가이아나',
#       'popltn_cn': None,
#       'popltn_cnt': 785514,
#       'popltn_cnt_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.88,
#       'popltn_growth_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2018},
#      {'country_eng_nm': 'Gambia',
#       'country_iso_alp2': 'GM',
#       'country_nm': '감비아',
#       'popltn_cn': None,
#       'popltn_cnt': 2508883,
#       'popltn_cnt_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.58,
#       'popltn_growth_src': "('19) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2019},
#      {'country_eng_nm': 'Gambia',
#       'country_iso_alp2': 'GM',
#       'country_nm': '감비아',
#       'popltn_cn': None,
#       'popltn_cnt': 2444916,
#       'popltn_cnt_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_growth': 2.64,
#       'popltn_growth_src': "('18) World Bank (최근 수정일 : 2024.11.13.)",
#       'popltn_month': None,
#       'popltn_year': 2018},
#      {'country_eng_nm': 'Bailiwick of Guernsey',
#       'country_iso_alp2': 'GG',
#       'country_nm': '건지',
#       'popltn_cn': None,
#       'popltn_cnt': 62506,
#       'popltn_cnt_src': None,
#       'popltn_growth': None,
#       'popltn_growth_src': None,
#       'popltn_month': 12,
#       'popltn_year': 2018},
#      {'country_eng_nm': 'Bailiwick of Guernsey',
#       'country_iso_alp2': 'GG',
#       'country_nm': '건지',
#       'popltn_cn': None,
#       'popltn_cnt': None,
#       'popltn_cnt_src': None,
#       'popltn_growth': None,
#       'popltn_growth_src': None,
#       'popltn_month': None,
#       'popltn_year': None}]},
#    'numOfRows': 10,
#    'pageNo': 1,
#    'totalCount': 450},
#   'header': {'resultCode': '0', 'resultMsg': '정상'}}}

# %%
import pprint

# %%
url = "http://www.google.com"


pprint.pp(requests.get(url).content)
# Out:
# (b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang='
#  b'"ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type'
#  b'"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.pn'
#  b'g" itemprop="image"><title>Google</title><script nonce="WN99qndfXovrWQ_Cu9et'
#  b'nw">(function(){var _g={kEI:\'5MfPZ9e9KIHD0PEP3bafsQM\',kEXPI:\'0,202792,34'
#  b'97502,655,435,538661,2872,2891,73050,16105,344796,247319,36310,6415,5241730,'
#  b'24,8834893,78,3,8,1,2,7,2,27977576,25228681,78017,45086,15165,8182,5935,6516'
#  b'1,6757,23878,9139,4600,328,6225,34310,19334,546,6427,3547,1342,13707,8213,74'
#  b'22,14521,3049,3732,33,4669,4372,17667,10672,10898,10441,7903,437,41,5607,803'
#  b'2,1,4922,1819,2893,1212,7737,13371,4945,2147,4617,5773,1202,3108,2065,8546,1'
#  b'731,3352,7608,921,4635,7703,1631,1634,3254,8,458,1638,893,35,3420,714,1768,1'
#  b'108,167,55,1027,1,828,80,138,1,3863,452,75,3207,569,2367,2249,870,846,2779,2'
#  b'31,1435,203,2,1,201,354,658,609,3143,1363,7,2193,1089,6,813,1231,2,1719,455,'
#  b'295,155,1,7,204,3143,12,1138,1936,492,278,227,1035,1370,813,903,23,238,1210,'
#  b'4,287,990,167,1319,624,2,488,78,616,6,1,680,61,202,372,11,583,949,399,356,17'
#  b'8,79,19,162,510,18,50,242,97,6,17,176,353,483,597,334,103,27,212,334,49,73,1'
#  b'0,531,3,2,346,454,8,1401,1395,243,109,376,2,466,33,131,648,477,622,628,495,6'
#  b'0,13,54,651,2,214,314,837,231,254,2,184,256,13,3,515,378,214,152,118,126,66,'
#  b'182,1002,833,94,183,96,444,115,469,620,156,3,12,457,226,416,357,1,685,2,1,2,'
#  b'2,2,34,1,438,71,4,2195,101,337,204,512,148,584,1245,12,105,806,337,277,20927'
#  b"988,404691,18,3223,1120,197,8,3873,12,1889,197,5742,1656,48,3766179,2244575'"
#  b",kBL:'Pnza',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.st"
#  b'vsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){googl'
#  b"e.sn='webhp';google.kHL='ko';})();(function(){\nvar g=this||self;function"
#  b' k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a'
#  b'){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode'
#  b';return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttr'
#  b'ibute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&wi'
#  b'ndow.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:'
#  b'a,glmm:1}),a="");return a}\nfunction r(a,b,d,c,h){var e="";b.search("&ei='
#  b'")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));va'
#  b'r f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cs'
#  b'hid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_2'
#  b'04")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;go'
#  b'ogle.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,'
#  b'h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.len'
#  b'gth;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};go'
#  b'ogle.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);('
#  b'function(){google.y={};google.sy=[];var d;(d=google).x||(d.x=function(a,b){i'
#  b'f(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];'
#  b'return!1});var e;(e=google).sx||(e.sx=function(a){google.sy.push(a)});google'
#  b'.lm=[];var f;(f=google).plm||(f.plm=function(a){google.lm.push.apply(google.'
#  b'lm,a)});google.lq=[];var g;(g=google).load||(g.load=function(a,b,c){google.l'
#  b'q.push([[a],b,c])});var h;(h=google).loadAll||(h.loadAll=function(a,b){googl'
#  b'e.lq.push([a,b])});google.bx=!1;var k;(k=google).lx||(k.lx=function(){});var'
#  b' l=[],m;(m=google).fce||(m.fce=function(a,b,c,n){l.push([a,b,c,n])});google.'
#  b'qce=l;}).call(this);google.f={};(function(){\ndocument.documentElement.ad'
#  b'dEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribut'
#  b'e("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!'
#  b'1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.'
#  b'addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document'
#  b'.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("dat'
#  b'a-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</scr'
#  b'ipt><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{hei'
#  b'ght:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{bor'
#  b'der-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:'
#  b'24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align'
#  b':top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb'
#  b'1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{c'
#  b'olor:#900 !important}\n</style><style>body,td,a,p,.h{font-family:&#44404;'
#  b'&#47548;,&#46027;&#50880;,sans-serif}.ko{font-size:9pt}body{margin:0;overflo'
#  b'w-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:'
#  b'17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style'
#  b':normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px sans-serif}.gsfs{f'
#  b'ont:17px sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0'
#  b' 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#0'
#  b'00}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:und'
#  b'erline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sb'
#  b'lc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{backgr'
#  b'ound:#f8f9fa;border:solid 1px;border-color:#dadce0 #70757a #70757a #dadce0;h'
#  b'eight:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}'
#  b'.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#000;bo'
#  b'rder:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px sans-serif'
#  b';vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}.'
#  b'Ucigb{width:458px}</style><script nonce="WN99qndfXovrWQ_Cu9etnw">(function()'
#  b"{window.google.erd={jsr:1,bv:2182,de:true,dpf:'N0BYxzVI4HVF1GA2u91TLRuZFc67G"
#  b"ARkaLZqnCuhBfU'};\nvar g=this||self;var k,l=(k=g.mei)!=null?k:1,m,p=(m=g."
#  b'diel)!=null?m:0,q,r=(q=g.sdo)!=null?q:!0,t=0,u,w=google.erd,x=w.jsr;google.m'
#  b'l=function(a,b,d,n,e){e=e===void 0?2:e;b&&(u=a&&a.message);d===void 0&&(d={}'
#  b');d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl'
#  b'(a,e,d,!0),null;b=d;if(x<0){window.console&&console.error(a,b);if(x===-2)thr'
#  b'ow a;b=!1}else b=!a||!a.message||a.message==="Error loading script"||t>=l&&!'
#  b'n?!1:!0;if(!b)return null;t++;d=d||{};b=encodeURIComponent;var c="/gen_204?a'
#  b'typ=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&'
#  b'srcpg="+b(google.sn)+"&jsr="+b(w.jsr)+\n"&bver="+b(w.bv);w.dpf&&(c+="&dpf'
#  b'="+b(w.dpf));var f=a.lineNumber;f!==void 0&&(c+="&line="+f);var h=a.fileName'
#  b';h&&(h.indexOf("-extension:/")>0&&(e=3),c+="&script="+b(h),f&&h===window.loc'
#  b'ation.href&&(f=document.documentElement.outerHTML.split("\\n")[f],c+="&ca'
#  b'd="+b(f?f.substring(0,300):"No script found.")));google.ple&&google.ple===1&'
#  b'&(e=2);c+="&jsel="+e;for(var v in d)c+="&",c+=b(v),c+="=",c+=b(d[v]);c=c+"&e'
#  b'msg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");c.length>=1228'
#  b'8&&(c=c.substr(0,12288));a=c;n||google.log(0,"",a);return a};window.onerror='
#  b'function(a,b,d,n,e){u!==a&&(a=e instanceof Error?e:Error(a),d===void 0||"lin'
#  b'eNumber"in a||(a.lineNumber=d),b===void 0||"fileName"in a||(a.fileName=b),go'
#  b'ogle.ml(a,!1,void 0,!1,a.name==="SyntaxError"||a.message.substring(0,11)==="'
#  b'SyntaxError"||a.message.indexOf("Script error")!==-1?3:p));u=null;r&&t>=l&&('
#  b'window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonc'
#  b'e="WN99qndfXovrWQ_Cu9etnw">(function(){var src=\'/images/nav_logo229.png\''
#  b';var iesg=false;document.body.onload = function(){window.n && window.n();if '
#  b'(document.images){new Image().src=src;}\nif (!iesg){document.f&&document.'
#  b'f.q.focus();document.gbqf&&document.gbqf.q.focus();}\n}\n})();</script><di'
#  b'v id="mngb"><div id=gbar><nobr><b class=gb1>&#44160;&#49353;</b> <a class=gb'
#  b'1 href="https://www.google.com/imghp?hl=ko&tab=wi">&#51060;&#48120;&#51648;<'
#  b'/a> <a class=gb1 href="http://maps.google.co.kr/maps?hl=ko&tab=wl">&#51648;&'
#  b'#46020;</a> <a class=gb1 href="https://play.google.com/?hl=ko&tab=w8">Play</'
#  b'a> <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube</a> <a class='
#  b'gb1 href="https://news.google.com/?tab=wn">&#45684;&#49828;</a> <a class=gb1'
#  b' href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="ht'
#  b'tps://drive.google.com/?tab=wo">&#46300;&#46972;&#51060;&#48652;</a> <a clas'
#  b's=gb1 style="text-decoration:none" href="https://www.google.co.kr/intl/ko/ab'
#  b'out/products?tab=wh"><u>&#45908;&#48372;&#44592;</u> &raquo;</a></nobr></div'
#  b'><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf c'
#  b'lass=gbf></span><span id=gbe></span><a href="http://www.google.co.kr/history'
#  b'/optout?hl=ko" class=gb4>&#50937; &#44592;&#47197;</a> | <a  href="/preferen'
#  b'ces?hl=ko" class=gb4>&#49444;&#51221;</a> | <a target=_top id=gb_70 href="ht'
#  b'tps://accounts.google.com/ServiceLogin?hl=ko&passive=true&continue=http://ww'
#  b'w.google.com/&ec=GAZAAQ" class=gb4>&#47196;&#44536;&#51064;</a></nobr></div>'
#  b'<div class=gbh style=left:0></div><div class=gbh style=right:0></div></div><'
#  b'center><br clear="all" id="lgpd"><div id="XjhHGf"><img alt="Google" height="'
#  b'92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_27'
#  b'2x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></di'
#  b'v><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr'
#  b' valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input'
#  b' name="ie" value="ISO-8859-1" type="hidden"><input value="ko" name="hl" type'
#  b'="hidden"><input name="source" type="hidden" value="hp"><input name="biw" ty'
#  b'pe="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32'
#  b'px;margin:4px 0"><div style="position:relative;zoom:1"><input class="lst Uci'
#  b'gb" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#000;padd'
#  b'ing-right:38px" autocomplete="off" value="" title="Google &#44160;&#49353;" '
#  b'maxlength="2048" name="q" size="57"><img src="/textinputassistant/tia.png" s'
#  b'tyle="position:absolute;cursor:pointer;right:5px;top:4px;z-index:300" data-s'
#  b'cript-url="/textinputassistant/13/ko_tia.js" id="tsuid_5MfPZ9e9KIHD0PEP3bafs'
#  b'QM_1" alt="" height="23" width="27"><script nonce="WN99qndfXovrWQ_Cu9etnw">('
#  b"function(){var id='tsuid_5MfPZ9e9KIHD0PEP3bafsQM_1';document.getElementById("
#  b"id).onclick = function(){var s = document.createElement('script');s.src = th"
#  b"is.getAttribute('data-script-url');document.body.appendChild(s);};})();</scr"
#  b'ipt></div></div><br style="line-height:0"><span class="ds"><span class="lsbb'
#  b'"><input class="lsb" value="Google &#44160;&#49353;" name="btnG" type="submi'
#  b't"></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="'
#  b'tsuid_5MfPZ9e9KIHD0PEP3bafsQM_2" value="I&#8217;m Feeling Lucky" name="btnI"'
#  b' type="submit"><script nonce="WN99qndfXovrWQ_Cu9etnw">(function(){var id'
#  b"='tsuid_5MfPZ9e9KIHD0PEP3bafsQM_2';document.getElementById(id).onclick = fun"
#  b'ction(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.fo'
#  b"rm.iflsig.disabled = false;}\nelse top.location='/doodles/';};})();</scri"
#  b'pt><input value="ACkRmUkAAAAAZ8_V9C2uj24aJa0sbzdulv88PAaDJYZ-" name="iflsig"'
#  b' type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap=""'
#  b' width="25%"><a href="/advanced_search?hl=ko&amp;authuser=0">&#44256;&#44553'
#  b';&#44160;&#49353;</a></td></tr></table><input id="gbv" name="gbv" type="hidd'
#  b'en" value="1"><script nonce="WN99qndfXovrWQ_Cu9etnw">(function(){var a,b="1"'
#  b';if(document&&document.getElementById)if(typeof XMLHttpRequest!="undefined")'
#  b'b="2";else if(typeof ActiveXObject!="undefined"){var c,d,e=["MSXML2.XMLHTTP.'
#  b'6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e['
#  b'c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if(a=="2"&&location.sear'
#  b'ch.indexOf("&gbv=2")==-1){var f=google.gbvu,g=document.getElementById("gbv")'
#  b';g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call'
#  b'(this);</script></form><div style="font-size:83%;min-height:3.5em"><br></div'
#  b'><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;'
#  b'text-align:center" id="WqQANb"><a href="/intl/ko/ads/">&#44305;&#44256;</a><'
#  b'a href="http://www.google.co.kr/intl/ko/services/">&#48708;&#51592;&#45768;&'
#  b'#49828; &#49556;&#47336;&#49496;</a><a href="/intl/ko/about.html">Google &#5'
#  b'1221;&#48372;</a><a href="http://www.google.com/setprefdomain?prefdom=KR&amp'
#  b';prev=http://www.google.co.kr/&amp;sig=K_4FoLurMeq-Q28-6fdn6xL3ll07o%3D">Goo'
#  b'gle.co.kr</a></div></div><p style="font-size:8pt;color:#70757a">&copy; 2025 '
#  b'- <a href="/intl/ko/policies/privacy/">&#44060;&#51064;&#51221;&#48372;&#523'
#  b'76;&#47532;&#48169;&#52840;</a> - <a href="/intl/ko/policies/terms/">&#50557'
#  b';&#44288;</a></p></span></center><script nonce="WN99qndfXovrWQ_Cu9etnw">(fun'
#  b'ction(){window.google.cdo={height:757,width:1440};(function(){var a=window.i'
#  b'nnerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMo'
#  b'de=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}i'
#  b'f(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g='
#  b'"/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=window.googl'
#  b'e&&window.google.kOPI||null;k&&(h+="&opi="+k);f.call(e,"","",g+h)};}).call(t'
#  b'his);})();</script>   <script nonce="WN99qndfXovrWQ_Cu9etnw">(function(){goo'
#  b"gle.xjs={basecomb:'/xjs/_/js/k\\x3dxjs.hp.en.rAh4dpbY6FA.es5.O/ck\\x3dxjs."
#  b'hp.6iNRfB8cQSM.L.X.O/am\\x3dBAAAAAAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACCAAAAA'
#  b'AAAAAAAgAMAAJgNwAEAAAEACBAAAAAAAAAAAAAAAEgAIAQAAAKAAAAgviMAIAAWAQDACw/d\\'
#  b"x3d1/ed\\x3d1/dg\\x3d0/ujg\\x3d1/rs\\x3dACT90oFMHvoN1uS8ocm2Mgzq1T5zpYS_Iw',"
#  b"basecss:'/xjs/_/ss/k\\x3dxjs.hp.6iNRfB8cQSM.L.X.O/am\\x3dBAAAAAAQAAAAAAAAA"
#  b'AAAAAAAAAAAAAAAAAAAAACAAAAAAAAAAAAAAAAAAJgBAAAAAAEACBAAAAAAAAAAAAAAAEgAIAQAA'
#  b"AKA/rs\\x3dACT90oEsmIJ5Y6-YVkDSN8iwP22a1L3pow',basejs:'/xjs/_/js/k\\x3dxjs"
#  b'.hp.en.rAh4dpbY6FA.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAACA'
#  b'AAAAAAAAAAAgAMAAAAMwAEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgviMAIAAWAQDACw/dg'
#  b"\\x3d0/rs\\x3dACT90oHH7GP6QTSfCryrfBzHdYtCVvwN4Q',excm:[]};})();</script> "
#  b'       <script nonce="WN99qndfXovrWQ_Cu9etnw">(function(){var u=\'/xjs/_/'
#  b'js/k\\x3dxjs.hp.en.rAh4dpbY6FA.es5.O/am\\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA'
#  b'AAAAAAAAACAAAAAAAAAAAAgAMAAAAMwAEAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgviMAIA'
#  b'AWAQDACw/d\\x3d1/ed\\x3d1/dg\\x3d3/rs\\x3dACT90oHH7GP6QTSfCryrfBzHdYtCVvwN4Q'
#  b"/m\\x3dsb_he,d';var st=1;var amd=1000;var mmd=0;var pod=true;var pop=fals"
#  b"e;var fp='';\nvar e=this||self;function f(){var a,b,d;if(b=a=(b=window.go"
#  b'ogle)==null?void 0:(d=b.ia)==null?void 0:d.r.B2Jtyd)b=a.m,b=b===1||b===5;ret'
#  b'urn b&&a.cbfd!=null&&a.cbvi!=null?a:void 0};function g(){var a=[u];if(!googl'
#  b'e.dp){for(var b=0;b<a.length;b++){var d=a[b],c=document.createElement("link"'
#  b');c.as="script";c.href=d;c.rel="preload";document.body.appendChild(c)}google'
#  b'.dp=!0}};google.ps===void 0&&(google.ps=[]);function h(){var a=u,b=function('
#  b'){};google.lx=google.stvsc?b:function(){k(a);google.lx=b};google.bx||google.'
#  b'lx()}function l(a,b){b&&(a.src=b);fp&&(a.fetchPriority=fp);var d=a.onload;a.'
#  b'onload=function(c){d&&d(c);google.ps=google.ps.filter(function(E){return a!='
#  b'=E})};google.ps.push(a);document.body.appendChild(a)}google.as=l;function k('
#  b'a){google.timers&&google.timers.load&&google.tick&&google.tick("load","xjsls'
#  b'");var b=document.createElement("script");b.onerror=function(){google.ple=1}'
#  b';b.onload=function(){google.ple=0};google.xjsus=void 0;l(b,a);google.aple=-1'
#  b';google.dp=!0};function m(a){var b=a.getAttribute("jscontroller");return(b=='
#  b'="UBXHI"||b==="R3fhkb"||b==="TSZEqd")&&a.hasAttribute("data-src")}function n'
#  b'(){for(var a=document.getElementsByTagName("img"),b=0,d=a.length;b<d;b++){va'
#  b'r c=a[b];if(c.hasAttribute("data-lzy_")&&Number(c.getAttribute("data-atf"))&'
#  b'1&&!m(c))return!0}return!1}for(var p=document.getElementsByTagName("img"),q='
#  b'0,r=p.length;q<r;++q){var t=p[q];Number(t.getAttribute("data-atf"))&1&&m(t)&'
#  b'&(t.src=t.getAttribute("data-src"))};var w,x,y,z,A,B,C,D;function F(){google'
#  b'.xjsu=u;e._F_jsUrl=u;A=function(){h()};w=!1;x=(st===1||st===3)&&!!google.caf'
#  b't&&!n();y=f();z=(st===2||st===3)&&!!y&&!n();B=pod;D=(C=pop)&&document.preren'
#  b'dering}function G(){w||x||z||D||(A(),w=!0)}\nsetTimeout(function(){google'
#  b'&&google.tick&&google.timers&&google.timers.load&&google.tick("load","xjspls'
#  b'");F();if(x||z||D){if(x){var a=function(){x=!1;G()};google.caft(a);window.se'
#  b'tTimeout(a,amd)}z&&(a=function(){z=!1;G()},y.cbvi.push(a),window.setTimeout('
#  b'a,mmd));D&&document.addEventListener("prerenderingchange",function(){D=!1;G('
#  b')},{once:!0});if(B||C)w||g()}else A()},0);})();window._ = window._ || {};win'
#  b'dow._DumpException = _._DumpException = function(e){throw e;};window._s = wi'
#  b'ndow._s || {};_s._DumpException = _._DumpException;window._qs = window._qs |'
#  b'| {};_qs._DumpException = _._DumpException;(function(){var t=[4,16384,0,0,0,'
#  b'0,0,545423360,0,1048576,3883008,57019664,3008,2097220,4194305,0,0,276824352,'
#  b'2097152,134217760,536880062,284736,48128];window._F_toggles = window._xjs_to'
#  b'ggles = t;})();window._F_installCss = window._F_installCss || function(css){'
#  b'};(function(){google.jl={bfl:0,dw:false,ine:false,ubm:false,uwp:true,vs:fals'
#  b"e};})();(function(){var pmc='{\\x22d\\x22:{},\\x22sb_he\\x22:{\\x22agen\\x"
#  b'22:false,\\x22cgen\\x22:false,\\x22client\\x22:\\x22heirloom-hp\\x22,\\x22d'
#  b'h\\x22:true,\\x22ds\\x22:\\x22\\x22,\\x22fl\\x22:true,\\x22host\\x22:\\x22'
#  b'google.com\\x22,\\x22jsonp\\x22:true,\\x22msgs\\x22:{\\x22cibl\\x22:\\x2'
#  b'2\\\\uac80\\\\uc0c9\\\\uc5b4 \\\\uc9c0\\\\uc6b0\\\\uae30\\x22,\\x22dym\\x22'
#  b':\\x22\\\\uc774\\\\uac83\\\\uc744 \\\\ucc3e\\\\uc73c\\\\uc168\\\\ub098\\'
#  b'\\uc694?\\x22,\\x22lcky\\x22:\\x22I\\\\u2019m Feeling Lucky\\x22,\\x22lml'
#  b'\\x22:\\x22\\\\uc790\\\\uc138\\\\ud788 \\\\uc54c\\\\uc544\\\\ubcf4\\\\ua'
#  b'e30\\x22,\\x22psrc\\x22:\\x22\\\\uac80\\\\uc0c9\\\\uc5b4\\\\uac00 \\\\u003'
#  b'Ca href\\x3d\\\\\\x22/history\\\\\\x22\\\\u003E\\\\uc6f9 \\\\uae30\\\\ub85d'
#  b'\\\\u003C/a\\\\u003E\\\\uc5d0\\\\uc11c \\\\uc0ad\\\\uc81c\\\\ub418\\\\uc'
#  b'5c8\\\\uc2b5\\\\ub2c8\\\\ub2e4.\\x22,\\x22psrl\\x22:\\x22\\\\uc0ad\\\\uc81'
#  b'c\\x22,\\x22sbit\\x22:\\x22\\\\uc774\\\\ubbf8\\\\uc9c0\\\\ub85c \\\\uac80\\'
#  b'\\uc0c9\\x22,\\x22srch\\x22:\\x22Google \\\\uac80\\\\uc0c9\\x22},\\x22ovr\\x'
#  b'22:{},\\x22pq\\x22:\\x22\\x22,\\x22rfs\\x22:[],\\x22stok\\x22:\\x22s21jDV'
#  b"rEEr-Kj8y3Urx-_EFJCec\\x22}}';google.pmc=JSON.parse(pmc);})();</script>  "
#  b'     </body></html>')

# %%
url = "http://apis.data.go.kr/1262000/CountryPopulationService2/getCountryPopulationList2?serviceKey=2xQhJhK7Olh7ATCkpQsV+o7K/GAmiuKEEH0xajI/OFYeBno7qU2LkF8DFSXLkqoQf88+xyWzgdvlb+Xebvg6fQ%3D%3D&pageNo=1&numOfRows=10&cond[country_nm::EQ]=%EA%B0%80%EB%82%98&cond[country_iso_alp2::EQ]=GH&returnType=JSON"


requests.get(url).content
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
import pprint

# %%
pprint.pp(requests.get(url).content)
# Out:
# (b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</e'
#  b'rrMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthM'
#  b'sg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</Ope'
#  b'nAPI_ServiceResponse>')

# %%
service_key = "dtbWOdJ/Cz5HE0DGLU+CRPe7pOW0NIQBUcGEqsHZaTRiYCI/5+zugwzQjcvuId7NPdg6rUiW+ft3fm7yqyD4pw=="

url= 'http://apis.data.go.kr/B190001/localGiftsPaymentV3/paymentsV3'

params = {'serviceKey' : service_key, 
        'page' : 1,
        'perPage' : 10 }

response = requests.get(url, params=params)

# %%
response.content
# Out:
# b'{"currentCount":10,"data":[{"card_use_amt":0,"crtr_ym":"201006","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":71820000,"stlm_nocs":534,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201007","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":80115000,"stlm_nocs":798,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201008","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":103695000,"stlm_nocs":774,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201009","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":214950000,"stlm_nocs":852,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201010","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":361980000,"stlm_nocs":1587,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201011","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":147585000,"stlm_nocs":1101,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201012","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":146220000,"stlm_nocs":1092,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201101","emd_cd":"41820000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":300180000,"stlm_nocs":1470,"usage_rgn_cd":"41820"},{"card_use_amt":0,"crtr_ym":"201101","emd_cd":"47850000","emd_nm":null,"mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":587610000,"stlm_nocs":861,"usage_rgn_cd":"47850"},{"card_use_amt":0,"crtr_ym":"201101","emd_cd":"47850250","emd_nm":"\xec\x99\x9c\xea\xb4\x80\xec\x9d\x8d","mbl_use_amt":0,"mbl_user_cnt":0,"par_ag":null,"par_gend":null,"stlm_amt":42660000,"stlm_nocs":177,"usage_rgn_cd":"47850"}],"matchCount":2190182,"page":1,"perPage":10,"totalCount":2190182}\n'

# %%
# bytes 데이터를 dict
data = json.loads(response.content)

# %%
data
# Out:
# {'currentCount': 10,
#  'data': [{'card_use_amt': 0,
#    'crtr_ym': '201006',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 71820000,
#    'stlm_nocs': 534,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201007',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 80115000,
#    'stlm_nocs': 798,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201008',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 103695000,
#    'stlm_nocs': 774,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201009',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 214950000,
#    'stlm_nocs': 852,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201010',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 361980000,
#    'stlm_nocs': 1587,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201011',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 147585000,
#    'stlm_nocs': 1101,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201012',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 146220000,
#    'stlm_nocs': 1092,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201101',
#    'emd_cd': '41820000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 300180000,
#    'stlm_nocs': 1470,
#    'usage_rgn_cd': '41820'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201101',
#    'emd_cd': '47850000',
#    'emd_nm': None,
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 587610000,
#    'stlm_nocs': 861,
#    'usage_rgn_cd': '47850'},
#   {'card_use_amt': 0,
#    'crtr_ym': '201101',
#    'emd_cd': '47850250',
#    'emd_nm': '왜관읍',
#    'mbl_use_amt': 0,
#    'mbl_user_cnt': 0,
#    'par_ag': None,
#    'par_gend': None,
#    'stlm_amt': 42660000,
#    'stlm_nocs': 177,
#    'usage_rgn_cd': '47850'}],
#  'matchCount': 2190182,
#  'page': 1,
#  'perPage': 10,
#  'totalCount': 2190182}

# %%
pd.DataFrame(data['data'])
# Out:
#    card_use_amt crtr_ym    emd_cd emd_nm  mbl_use_amt  mbl_user_cnt par_ag  \
# 0             0  201006  41820000   None            0             0   None
# 1             0  201007  41820000   None            0             0   None
# 2             0  201008  41820000   None            0             0   None
# 3             0  201009  41820000   None            0             0   None
# 4             0  201010  41820000   None            0             0   None
# 5             0  201011  41820000   None            0             0   None
# 6             0  201012  41820000   None            0             0   None
# 7             0  201101  41820000   None            0             0   None
# 8             0  201101  47850000   None            0             0   None
# 9             0  201101  47850250    왜관읍            0             0   None
#
#   par_gend   stlm_amt  stlm_nocs usage_rgn_cd
# 0     None   71820000        534        41820
# 1     None   80115000        798        41820
# 2     None  103695000        774        41820
# 3     None  214950000        852        41820
# 4     None  361980000       1587        41820
# 5     None  147585000       1101        41820
# 6     None  146220000       1092        41820
# 7     None  300180000       1470        41820
# 8     None  587610000        861        47850
# 9     None   42660000        177        47850

# %%
url = "https://dataapi.wehago.com/data/?dataset_key=DATASET_KTNET_68"

header = {
    'apicode' : 'f865e7be-5f88-49ff-a462-31b3c97b582e'
}


response = requests.get(url, headers=header)

# %%
# Out:
# <Response [200]>

# %%
data2 = json.loads(response.content)

# %%
data2
# Out:
# {'schema': {'fields': [{'number': 1,
#     'column_code': 'STDR_DTTE',
#     'column_name': '기준 일자',
#     'data_type': 'string',
#     'column_desc': 'YYYYMMDD'},
#    {'number': 2,
#     'column_code': 'EHGT_SE',
#     'column_name': '환율 구분',
#     'data_type': 'string',
#     'column_desc': '1: 전신환매도율(과세환율)'},
#    {'number': 3,
#     'column_code': 'CRNCY_CODE',
#     'column_name': '통화 코드',
#     'data_type': 'string',
#     'column_desc': '통화코드'},
#    {'number': 4,
#     'column_code': 'EHGT',
#     'column_name': '환율',
#     'data_type': 'decimal',
#     'column_desc': '환율'}]},
#  'data': [{'index': 0,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 337.0},
#   {'index': 1,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 98.0},
#   {'index': 2,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 802.0},
#   {'index': 3,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 15.0},
#   {'index': 4,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 33.0},
#   {'index': 5,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3282.0},
#   {'index': 6,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 211.0},
#   {'index': 7,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 880.0},
#   {'index': 8,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1278.0},
#   {'index': 9,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 10,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 174.0},
#   {'index': 11,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 49.0},
#   {'index': 12,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 687.0},
#   {'index': 13,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 180.0},
#   {'index': 14,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 79.0},
#   {'index': 15,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 808.0},
#   {'index': 16,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1344.0},
#   {'index': 17,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 226.0},
#   {'index': 18,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 205.0},
#   {'index': 19,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1519.0},
#   {'index': 20,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 160.0},
#   {'index': 21,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 22,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 23,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 353.0},
#   {'index': 24,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 17.0},
#   {'index': 25,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 69.0},
#   {'index': 26,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1155.0},
#   {'index': 27,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 12.0},
#   {'index': 28,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 4005.0},
#   {'index': 29,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 30,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 31,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 155.0},
#   {'index': 32,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 51.0},
#   {'index': 33,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 286.0},
#   {'index': 34,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 610.0},
#   {'index': 35,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 122.0},
#   {'index': 36,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 37,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 753.0},
#   {'index': 38,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 39,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 8.0},
#   {'index': 40,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 295.0},
#   {'index': 41,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 338.0},
#   {'index': 42,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 17.0},
#   {'index': 43,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 330.0},
#   {'index': 44,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 127.0},
#   {'index': 45,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 873.0},
#   {'index': 46,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 45.0},
#   {'index': 47,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 48,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 177.0},
#   {'index': 49,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 50,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1238.0},
#   {'index': 51,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 52,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 67870.0},
#   {'index': 53,
#    'STDR_DTTE': '20200513',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 67.0},
#   {'index': 54,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 328.0},
#   {'index': 55,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 56,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 844.0},
#   {'index': 57,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 58,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 59,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3195.0},
#   {'index': 60,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 243.0},
#   {'index': 61,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 900.0},
#   {'index': 62,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1279.0},
#   {'index': 63,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 64,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 170.0},
#   {'index': 65,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 52.0},
#   {'index': 66,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 702.0},
#   {'index': 67,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 184.0},
#   {'index': 68,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 69,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 825.0},
#   {'index': 70,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1373.0},
#   {'index': 71,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 231.0},
#   {'index': 72,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 209.0},
#   {'index': 73,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1538.0},
#   {'index': 74,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 156.0},
#   {'index': 75,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 76,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 9.0},
#   {'index': 77,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 352.0},
#   {'index': 78,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 79,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 80,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1128.0},
#   {'index': 81,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 82,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3923.0},
#   {'index': 83,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 84,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 85,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 151.0},
#   {'index': 86,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 87,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 284.0},
#   {'index': 88,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 623.0},
#   {'index': 89,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 130.0},
#   {'index': 90,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 91,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 788.0},
#   {'index': 92,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 93,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 94,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 309.0},
#   {'index': 95,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 329.0},
#   {'index': 96,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 18.0},
#   {'index': 97,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 321.0},
#   {'index': 98,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 131.0},
#   {'index': 99,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 872.0},
#   {'index': 100,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 101,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 102,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 178.0},
#   {'index': 103,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 104,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1206.0},
#   {'index': 105,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 106,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 66696.0},
#   {'index': 107,
#    'STDR_DTTE': '20200611',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 73.0},
#   {'index': 108,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 334.0},
#   {'index': 109,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 110,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 844.0},
#   {'index': 111,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 112,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 113,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3249.0},
#   {'index': 114,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 235.0},
#   {'index': 115,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 904.0},
#   {'index': 116,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1293.0},
#   {'index': 117,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 118,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 119,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 52.0},
#   {'index': 120,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 705.0},
#   {'index': 121,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 185.0},
#   {'index': 122,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 76.0},
#   {'index': 123,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 829.0},
#   {'index': 124,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1379.0},
#   {'index': 125,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 232.0},
#   {'index': 126,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 210.0},
#   {'index': 127,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1540.0},
#   {'index': 128,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 158.0},
#   {'index': 129,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 130,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 9.0},
#   {'index': 131,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 356.0},
#   {'index': 132,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 133,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 134,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1146.0},
#   {'index': 135,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 12.0},
#   {'index': 136,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3987.0},
#   {'index': 137,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 138,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 139,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 154.0},
#   {'index': 140,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 141,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 287.0},
#   {'index': 142,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 626.0},
#   {'index': 143,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 129.0},
#   {'index': 144,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 145,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 792.0},
#   {'index': 146,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 147,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 148,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 309.0},
#   {'index': 149,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 337.0},
#   {'index': 150,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 18.0},
#   {'index': 151,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 327.0},
#   {'index': 152,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 132.0},
#   {'index': 153,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 880.0},
#   {'index': 154,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 155,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 156,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 179.0},
#   {'index': 157,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 158,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1226.0},
#   {'index': 159,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 160,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 68068.0},
#   {'index': 161,
#    'STDR_DTTE': '20200618',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 71.0},
#   {'index': 162,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 330.0},
#   {'index': 163,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 99.0},
#   {'index': 164,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 840.0},
#   {'index': 165,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 166,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 167,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3214.0},
#   {'index': 168,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 229.0},
#   {'index': 169,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 894.0},
#   {'index': 170,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1283.0},
#   {'index': 171,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 172,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 172.0},
#   {'index': 173,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 174,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 698.0},
#   {'index': 175,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 183.0},
#   {'index': 176,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 177,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 821.0},
#   {'index': 178,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1366.0},
#   {'index': 179,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 230.0},
#   {'index': 180,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 208.0},
#   {'index': 181,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1514.0},
#   {'index': 182,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 157.0},
#   {'index': 183,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 184,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 9.0},
#   {'index': 185,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 352.0},
#   {'index': 186,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 187,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 188,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1129.0},
#   {'index': 189,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 190,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3944.0},
#   {'index': 191,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 192,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 193,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 152.0},
#   {'index': 194,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 54.0},
#   {'index': 195,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 283.0},
#   {'index': 196,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 620.0},
#   {'index': 197,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 128.0},
#   {'index': 198,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 199,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 787.0},
#   {'index': 200,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 201,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 202,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 305.0},
#   {'index': 203,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 331.0},
#   {'index': 204,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 17.0},
#   {'index': 205,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 324.0},
#   {'index': 206,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 130.0},
#   {'index': 207,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 871.0},
#   {'index': 208,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 45.0},
#   {'index': 209,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 39.0},
#   {'index': 210,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 177.0},
#   {'index': 211,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 212,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1213.0},
#   {'index': 213,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 214,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 68801.0},
#   {'index': 215,
#    'STDR_DTTE': '20200702',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 71.0},
#   {'index': 216,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 326.0},
#   {'index': 217,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 103.0},
#   {'index': 218,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 873.0},
#   {'index': 219,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 220,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 35.0},
#   {'index': 221,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3180.0},
#   {'index': 222,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 227.0},
#   {'index': 223,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 916.0},
#   {'index': 224,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1308.0},
#   {'index': 225,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 226,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 176.0},
#   {'index': 227,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 54.0},
#   {'index': 228,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 725.0},
#   {'index': 229,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 190.0},
#   {'index': 230,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 76.0},
#   {'index': 231,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 852.0},
#   {'index': 232,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1417.0},
#   {'index': 233,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 238.0},
#   {'index': 234,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 216.0},
#   {'index': 235,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1578.0},
#   {'index': 236,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 155.0},
#   {'index': 237,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 238,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 239,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 355.0},
#   {'index': 240,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 241,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 73.0},
#   {'index': 242,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1128.0},
#   {'index': 243,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 244,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3919.0},
#   {'index': 245,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 246,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 247,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 150.0},
#   {'index': 248,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 249,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 288.0},
#   {'index': 250,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 643.0},
#   {'index': 251,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 134.0},
#   {'index': 252,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 253,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 803.0},
#   {'index': 254,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 255,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 256,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 320.0},
#   {'index': 257,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 330.0},
#   {'index': 258,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 16.0},
#   {'index': 259,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 320.0},
#   {'index': 260,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 137.0},
#   {'index': 261,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 877.0},
#   {'index': 262,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 47.0},
#   {'index': 263,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 38.0},
#   {'index': 264,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 161.0},
#   {'index': 265,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 266,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1199.0},
#   {'index': 267,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 268,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 74415.0},
#   {'index': 269,
#    'STDR_DTTE': '20200908',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 72.0},
#   {'index': 270,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 325.0},
#   {'index': 271,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 103.0},
#   {'index': 272,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 871.0},
#   {'index': 273,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 274,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 35.0},
#   {'index': 275,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3162.0},
#   {'index': 276,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 226.0},
#   {'index': 277,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 904.0},
#   {'index': 278,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1313.0},
#   {'index': 279,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 280,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 176.0},
#   {'index': 281,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 53.0},
#   {'index': 282,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 722.0},
#   {'index': 283,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 190.0},
#   {'index': 284,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 76.0},
#   {'index': 285,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 849.0},
#   {'index': 286,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1413.0},
#   {'index': 287,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 238.0},
#   {'index': 288,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 215.0},
#   {'index': 289,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1537.0},
#   {'index': 290,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 154.0},
#   {'index': 291,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 292,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 293,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 349.0},
#   {'index': 294,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 295,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 73.0},
#   {'index': 296,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1131.0},
#   {'index': 297,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 298,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3901.0},
#   {'index': 299,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 300,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 301,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 150.0},
#   {'index': 302,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 56.0},
#   {'index': 303,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 289.0},
#   {'index': 304,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 641.0},
#   {'index': 305,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 132.0},
#   {'index': 306,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 307,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 801.0},
#   {'index': 308,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 309,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 310,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 317.0},
#   {'index': 311,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 325.0},
#   {'index': 312,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 16.0},
#   {'index': 313,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 318.0},
#   {'index': 314,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 136.0},
#   {'index': 315,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 876.0},
#   {'index': 316,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 47.0},
#   {'index': 317,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 38.0},
#   {'index': 318,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 159.0},
#   {'index': 319,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 320,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1192.0},
#   {'index': 321,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 322,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 74936.0},
#   {'index': 323,
#    'STDR_DTTE': '20200916',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 73.0},
#   {'index': 324,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 323.0},
#   {'index': 325,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 102.0},
#   {'index': 326,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 869.0},
#   {'index': 327,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 328,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 35.0},
#   {'index': 329,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3148.0},
#   {'index': 330,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 227.0},
#   {'index': 331,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 903.0},
#   {'index': 332,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1307.0},
#   {'index': 333,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 334,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 175.0},
#   {'index': 335,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 53.0},
#   {'index': 336,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 719.0},
#   {'index': 337,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 189.0},
#   {'index': 338,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 339,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 846.0},
#   {'index': 340,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1407.0},
#   {'index': 341,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 237.0},
#   {'index': 342,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 215.0},
#   {'index': 343,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1540.0},
#   {'index': 344,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 153.0},
#   {'index': 345,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 346,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 347,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 347.0},
#   {'index': 348,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 349,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 73.0},
#   {'index': 350,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1133.0},
#   {'index': 351,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 352,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3882.0},
#   {'index': 353,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 354,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 355,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 149.0},
#   {'index': 356,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 57.0},
#   {'index': 357,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 287.0},
#   {'index': 358,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 639.0},
#   {'index': 359,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 131.0},
#   {'index': 360,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 361,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 803.0},
#   {'index': 362,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 25.0},
#   {'index': 363,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 364,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 316.0},
#   {'index': 365,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 327.0},
#   {'index': 366,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 16.0},
#   {'index': 367,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 317.0},
#   {'index': 368,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 135.0},
#   {'index': 369,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 875.0},
#   {'index': 370,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 47.0},
#   {'index': 371,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 38.0},
#   {'index': 372,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 157.0},
#   {'index': 373,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 374,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1187.0},
#   {'index': 375,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 376,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 73913.0},
#   {'index': 377,
#    'STDR_DTTE': '20200918',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 74.0},
#   {'index': 378,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 322.0},
#   {'index': 379,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 380,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 834.0},
#   {'index': 381,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 382,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 383,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3134.0},
#   {'index': 384,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 215.0},
#   {'index': 385,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 885.0},
#   {'index': 386,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1275.0},
#   {'index': 387,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 2.0},
#   {'index': 388,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 389,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 390,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 705.0},
#   {'index': 391,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 185.0},
#   {'index': 392,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 393,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 829.0},
#   {'index': 394,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1380.0},
#   {'index': 395,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 232.0},
#   {'index': 396,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 210.0},
#   {'index': 397,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1507.0},
#   {'index': 398,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 152.0},
#   {'index': 399,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 400,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 401,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 340.0},
#   {'index': 402,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 403,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 404,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1121.0},
#   {'index': 405,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 406,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3859.0},
#   {'index': 407,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 408,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 409,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 148.0},
#   {'index': 410,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 53.0},
#   {'index': 411,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 284.0},
#   {'index': 412,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 626.0},
#   {'index': 413,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 124.0},
#   {'index': 414,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 415,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 774.0},
#   {'index': 416,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 417,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 418,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 304.0},
#   {'index': 419,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 325.0},
#   {'index': 420,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 15.0},
#   {'index': 421,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 315.0},
#   {'index': 422,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 130.0},
#   {'index': 423,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 860.0},
#   {'index': 424,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 425,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 37.0},
#   {'index': 426,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 155.0},
#   {'index': 427,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 40.0},
#   {'index': 428,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1182.0},
#   {'index': 429,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 430,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 70999.0},
#   {'index': 431,
#    'STDR_DTTE': '20200925',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 70.0},
#   {'index': 432,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 322.0},
#   {'index': 433,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 101.0},
#   {'index': 434,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 846.0},
#   {'index': 435,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 436,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 437,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3132.0},
#   {'index': 438,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 208.0},
#   {'index': 439,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 888.0},
#   {'index': 440,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1287.0},
#   {'index': 441,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 1.0},
#   {'index': 442,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 443,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 444,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 708.0},
#   {'index': 445,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DKK',
#    'EHGT': 186.0},
#   {'index': 446,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EGP',
#    'EHGT': 75.0},
#   {'index': 447,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ESP',
#    'EHGT': 832.0},
#   {'index': 448,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'EUR',
#    'EHGT': 1384.0},
#   {'index': 449,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FIM',
#    'EHGT': 233.0},
#   {'index': 450,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'FRF',
#    'EHGT': 211.0},
#   {'index': 451,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'GBP',
#    'EHGT': 1527.0},
#   {'index': 452,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HKD',
#    'EHGT': 152.0},
#   {'index': 453,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'HUF',
#    'EHGT': 4.0},
#   {'index': 454,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'IDR',
#    'EHGT': 8.0},
#   {'index': 455,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ILS',
#    'EHGT': 345.0},
#   {'index': 456,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'INR',
#    'EHGT': 16.0},
#   {'index': 457,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ITL',
#    'EHGT': 71.0},
#   {'index': 458,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'JPY',
#    'EHGT': 1119.0},
#   {'index': 459,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KES',
#    'EHGT': 11.0},
#   {'index': 460,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KWD',
#    'EHGT': 3857.0},
#   {'index': 461,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'KZT',
#    'EHGT': 3.0},
#   {'index': 462,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MNT',
#    'EHGT': 0.0},
#   {'index': 463,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MOP',
#    'EHGT': 148.0},
#   {'index': 464,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MXN',
#    'EHGT': 55.0},
#   {'index': 465,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'MYR',
#    'EHGT': 284.0},
#   {'index': 466,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NLG',
#    'EHGT': 628.0},
#   {'index': 467,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NOK',
#    'EHGT': 127.0},
#   {'index': 468,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NPR',
#    'EHGT': 10.0},
#   {'index': 469,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'NZD',
#    'EHGT': 784.0},
#   {'index': 470,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PHP',
#    'EHGT': 24.0},
#   {'index': 471,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PKR',
#    'EHGT': 7.0},
#   {'index': 472,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'PLN',
#    'EHGT': 308.0},
#   {'index': 473,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'QAR',
#    'EHGT': 325.0},
#   {'index': 474,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'RUB',
#    'EHGT': 15.0},
#   {'index': 475,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SAR',
#    'EHGT': 315.0},
#   {'index': 476,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SEK',
#    'EHGT': 132.0},
#   {'index': 477,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SGD',
#    'EHGT': 866.0},
#   {'index': 478,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'SKK',
#    'EHGT': 46.0},
#   {'index': 479,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'THB',
#    'EHGT': 37.0},
#   {'index': 480,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TRY',
#    'EHGT': 152.0},
#   {'index': 481,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'TWD',
#    'EHGT': 41.0},
#   {'index': 482,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'USD',
#    'EHGT': 1181.0},
#   {'index': 483,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'VND',
#    'EHGT': 5.0},
#   {'index': 484,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'XAU',
#    'EHGT': 72210.0},
#   {'index': 485,
#    'STDR_DTTE': '20201005',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ZAR',
#    'EHGT': 72.0},
#   {'index': 486,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AED',
#    'EHGT': 318.0},
#   {'index': 487,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'ATS',
#    'EHGT': 100.0},
#   {'index': 488,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'AUD',
#    'EHGT': 844.0},
#   {'index': 489,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BDT',
#    'EHGT': 14.0},
#   {'index': 490,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BEF',
#    'EHGT': 34.0},
#   {'index': 491,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BHD',
#    'EHGT': 3097.0},
#   {'index': 492,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'BRL',
#    'EHGT': 212.0},
#   {'index': 493,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CAD',
#    'EHGT': 889.0},
#   {'index': 494,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CHF',
#    'EHGT': 1283.0},
#   {'index': 495,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CLP',
#    'EHGT': 1.0},
#   {'index': 496,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CNY',
#    'EHGT': 173.0},
#   {'index': 497,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'CZK',
#    'EHGT': 51.0},
#   {'index': 498,
#    'STDR_DTTE': '20201012',
#    'EHGT_SE': '1',
#    'CRNCY_CODE': 'DEM',
#    'EHGT': 706.0}]}

# %%
df = pd.DataFrame(data2['data'])

# %%
df.drop('index', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['STDR_DTTE', 'EHGT_SE', 'CRNCY_CODE', 'EHGT'], dtype='object')

# %%
cols_data = data2['schema']['fields']

# %%
# cols_data에서 column_name의 value만 추출하여 리스트로 생성
cols_list = list(
    map(
        lambda x: x['column_name'],
        cols_data
    )
)

# %%
cols_dict = {}

for cols in cols_data:
    # cols는 cols_data의 각 원소들이 대입
    # cols_dict에 key(column_code) : value(column_name)추가
    cols_dict[cols['column_code']] = cols['column_name']

print(cols_dict)
# Out:
# {'STDR_DTTE': '기준 일자', 'EHGT_SE': '환율 구분', 'CRNCY_CODE': '통화 코드', 'EHGT': '환율'}

# %%
df.rename(
    columns = cols_dict
)
# Out:
#         기준 일자 환율 구분 통화 코드      환율
# 0    20200513     1   AED   337.0
# 1    20200513     1   ATS    98.0
# 2    20200513     1   AUD   802.0
# 3    20200513     1   BDT    15.0
# 4    20200513     1   BEF    33.0
# ..        ...   ...   ...     ...
# 494  20201012     1   CHF  1283.0
# 495  20201012     1   CLP     1.0
# 496  20201012     1   CNY   173.0
# 497  20201012     1   CZK    51.0
# 498  20201012     1   DEM   706.0
#
# [499 rows x 4 columns]

# %%
df.columns = cols_list

# %%
df.to_excel("../test.xlsx", index=False)
